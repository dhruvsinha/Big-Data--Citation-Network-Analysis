# %% [markdown]
# # Predicting citation count using Gradient-Boosted Decision Trees on paper abstracts

# %%
from pyspark import SparkFiles, SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer, IDF, VectorAssembler
from pyspark.ml.regression import GBTRegressor
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline
from pyspark.sql.functions import col

# %%
spark = SparkSession.builder.enableHiveSupport().appName('CitationCount').getOrCreate()
sc = spark.sparkContext

# %%
df_filter = spark.read.option("header", True).csv("gs://msca-bdp-student-gcs/Group5_Final_Project/raw_data/clean_filtered")

# %%
df_filter = df_filter.select('abstract', 'n_citation')

# %%
(training_data, testing_data) = df_filter.randomSplit([0.8, 0.2])

# %%
tokenizer = Tokenizer(inputCol="abstract", outputCol="words")
remover = StopWordsRemover(inputCol="words", outputCol="filtered")
cv = CountVectorizer(inputCol="filtered", outputCol="raw_features")
idf = IDF(inputCol="raw_features", outputCol="features")
assembler = VectorAssembler(inputCols=["features"], outputCol="assembled_features")
gbt = GBTRegressor(featuresCol="features", labelCol="n_citation", maxIter=10)

# %%
pipeline = Pipeline(stages=[tokenizer, remover, cv, idf, assembler, gbt])

# %%
model = pipeline.fit(training_data)
# Out:
# 23/03/06 08:03:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 23/03/06 08:04:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.2 MiB
# 23/03/06 08:04:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 6.2 MiB
# 23/03/06 08:04:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 10.2 MiB
# 23/03/06 08:04:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 10.2 MiB
# 23/03/06 08:05:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 12.8 MiB
# 23/03/06 08:05:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1034.3 KiB
# 23/03/06 08:05:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:07:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:07:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:08:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:08:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:08:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:09:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:09:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:10:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:10:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:11:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:11:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:12:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:12:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:13:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:13:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:14:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:14:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:14:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:15:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:15:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:16:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:16:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:17:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:17:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:18:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:18:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:19:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:19:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:19:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:20:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:21:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:21:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:21:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 23/03/06 08:22:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:22:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:23:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:23:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:24:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:24:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:24:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:25:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:25:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:26:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:26:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:27:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:27:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:28:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:28:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB
# 23/03/06 08:28:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 14.3 MiB

# %%
predictions = model.transform(testing_data)

# %%
evaluator = RegressionEvaluator(labelCol="n_citation", predictionCol="prediction", metricName="rmse")

# %%
rmse = evaluator.evaluate(predictions)
# Out:
# 23/03/06 08:29:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 10.2 MiB
# 23/03/06 08:29:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 10.2 MiB

# %%
rmse
# Out:
# 215.83083874557414
